# %%
import requests, csv, numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://ainsworthsports.com/soccer_player_rankings_all_time_1_to_1000.htm"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
tags = soup.find_all("td")
df = pd.DataFrame()
players = pd.DataFrame(columns={"id", "player_name"})
added_players = []
bad_names = []
for i in range(29, len(tags), 4): #jump to first name tag, names are every 4 tags
    player_name = tags[i].text.strip()
    id_response_json = requests.get(f"http://localhost:8000/players/search/{player_name}").json()
    if "results" in id_response_json and id_response_json["results"]:
        print(player_name)
        player_id = ""
        for res in id_response_json['results']:
            if are_equal_ignore_accents(player_name, res["name"]):
                player_id=res["id"]
                break
        if not player_id: player_id = id_response_json['results'][0]["id"]
        teams_response = requests.get(f"http://localhost:8000/players/{player_id}/transfers")
        players = pd.concat([players, pd.DataFrame([{"id": int(player_id), "player_name": player_name}])], ignore_index=True)
        df = pd.concat([df, pd.DataFrame([teams_response.json()])], ignore_index=True)
    else:
        bad_names.append(player_name)
df
# Out:
# Pele
# Cristiano Ronaldo
# Lionel Messi
# Diego Maradona
# Franz Beckenbauer
# Michel Platini
# Johan Cruyff
# Ronaldo
# Marco van Basten
# Eusebio
# Gerd Muller
# Bobby Charlton
# Karl-Heinz Rummenigge
# Zinedine Zidane
# Lothar Matthaus
# Ruud Gullit
# Lev Yashin
# Andriy Shevchenko
# Raymond Kopa
# Gianni Rivera
# Bobby Moore
# Franco Baresi
# Rivaldo
# Luis Figo
# Florian Albert
# Denis Law
# Michael Owen
# Roberto Baggio
# Robert Lewandowski
# Hristo Stoichkov
# Ferenc Puskas
# Ronaldinho
# Paolo Rossi
# Kaka
# Luka Modric
# Alfredo Di Stefano
# Pavel Nedved
# Jean-Pierre Papin
# Oleg Blokhin
# Garrincha
# Kevin Keegan
# George Best
# Allan Simonsen
# Omar Sivori
# Josef Masopust
# Matthias Sammer
# Fabio Cannavaro
# Romario
# Mario Kempes
# Zico
# George Weah
# Stanley Matthews
# Igor Belanov
# Paolo Maldini
# Jurgen Klinsmann
# Kenny Dalglish
# David Beckham
# Thierry Henry
# Andres Iniesta
# Dino Zoff
# John Charles
# Raul
# Gianluigi Buffon
# Roberto Carlos
# Gabriel Batistuta
# Giacinto Facchetti
# Gheorghe Hagi
# Frank Lampard
# Gary Lineker
# Paul Breitner
# Ian Rush
# Dennis Bergkamp
# Preben Elkjaer
# Eric Cantona
# Deco
# Gordon Banks
# Davor Suker
# Rob Rensenbrink
# Bernd Schuster
# Luigi Riva
# Gunter Netzer
# Alessandro Mazzola
# Alain Giresse
# Hans Krankl
# Helmut Rahn
# Dejan Savicevic
# Paulo Futre
# Predrag Mijatovic
# Jean Tigana
# Jairzinho
# Rivelino
# Giuseppe Meazza
# Didi
# Billy Wright
# Salvatore Schillaci
# Darko Pancev
# Xavi
# Neymar
# Michael Laudrup
# Zbigniew Boniek
# Dragan Dzajic
# Steven Gerrard
# Alan Shearer
# Manuel Neuer
# Peter Schmeichel
# Ruud Krol
# Fernando Torres
# Jimmy Greaves
# Franck Ribery
# Uwe Seeler
# Kazimierz Deyna
# Frank Rijkaard
# Oliver Kahn
# Mevlut Erdinc
# Geoffrey Jourdren
# Ron-Robert Zieler
# Patrik Berger
# David Ospina
# Remy Cabella
# Kasper Schmeichel
# Paul Ince
# James Beattie
# Jermaine Jenas
# Cheick Diabate
# Ugo Ehiogu
# Mark Noble
# Wahbi Khazri
# Aleksandar Kolarov
# Benoit Costil
# Kevin Phillips
# Yohan Cabaye
# Denis Irwin
# Ben Foster
# Rildo
# Tim Sherwood
# Darren Anderton
# Ryad Boudebouz
# Clint Dempsey
# Mark Bosnich
# Andre Schurrle
# Ilkay Gundogan
# Lukasz Piszczek
# Lukasz Fabianski
# Ivan Perisic
# Timo Werner
# Ian Walker
# Ralf Fahrmann
# Daniel Sturridge
# Yunus Malli
# Dennis Wise
# Tony Cottee
# Rene Adler
# Paolo Di Canio
# Lewis Holtby
# Simon Davies
# Florian Thauvin
# Willian
# Neil Sullivan
# Matthew Taylor
# Seamus Coleman
# Shinji Kagawa
# Kevin Davies
# Paulo Wanchope
# Oyvind Leonhardsen
# Joleon Lescott
# Oscar Wendt
# Alexander Meier
# Shaka Hislop
# Martin Harnik
# Diego Benaglio
# David Luiz
# Paul Jones
# Don Hutchison
# Hermann Hreidarsson
# Andrej Kramaric
# Asmir Begovic
# Adam Johnson
# David Dunn
# Morgan Sanson
# Gareth Southgate
# Paul Scharner
# Marcell Jansen
# Louis Saha
# Souleymane Camara
# Kevin Kilbane
# Andre Hahn
# Boudewijn Zenden
# Yossi Benayoun
# Vincent Kompany
# Craig Bellamy
# Christian Benteke
# Romain Hamouma
# Ashley Cole
# Glen Johnson
# Marko Arnautovic
# Ruel Fox
# Ivica Olic
# Julian Brandt
# Robert Huth
# Christophe Jallet
# Jordan Henderson
# Shinji Okazaki
# Anthony Martial
# Craig Gardner
#          id                                          transfers  \
# 0     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# 1      8198  [{'id': '4197140', 'from': {'clubID': '515', '...
# 2     28003  [{'id': '4418847', 'from': {'clubID': '583', '...
# 3      8024  [{'id': '231513', 'from': {'clubID': '189', 'c...
# 4     72347  [{'id': '186730', 'from': {'clubID': '4835', '...
# ..      ...                                                ...
# 963   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 964   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 965   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 966  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 967   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0    [Bauru Atletico Clube (1952-1956), FC Santos (...
# 1                           [CF Andorinha (1992-1995)]
# 2    [Grandoli FC (1992-1995), Newell's Old Boys (1...
# 3                                                  NaN
# 4         [SC 1906 München, FC Bayern München (-1964)]
# ..                                                 ...
# 963  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 964  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 965                             [Takarazuka Junior FC]
# 966  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 967                                                NaN
#
#                       updatedAt
# 0    2024-11-26T22:21:31.862067
# 1    2024-11-26T22:21:32.848502
# 2    2024-11-26T22:21:34.169456
# 3    2024-11-26T22:21:37.041589
# 4    2024-11-26T22:21:45.622650
# ..                          ...
# 963  2024-11-26T22:52:30.260835
# 964  2024-11-26T22:52:31.366344
# 965  2024-11-26T22:52:32.315595
# 966  2024-11-26T22:52:33.293869
# 967  2024-11-26T22:52:34.763699
#
# [968 rows x 4 columns]

# %%
import unicodedata

def are_equal_ignore_accents(str1, str2):
    # Normalize the strings to remove accents
    normalized_str1 = unicodedata.normalize('NFKD', str1).encode('ascii', 'ignore').decode('utf-8')
    normalized_str2 = unicodedata.normalize('NFKD', str2).encode('ascii', 'ignore').decode('utf-8')
    
    # Compare the normalized strings
    return normalized_str1 == normalized_str2
are_equal_ignore_accents("resume", "resumé")
# Out:
# True

# %%
df = df[df['transfers'].notna()]
df.shape
# Out:
# (967, 4)

# %%
df
# Out:
#          id                                          transfers  \
# 0     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# 1      8198  [{'id': '4197140', 'from': {'clubID': '515', '...
# 2     28003  [{'id': '4418847', 'from': {'clubID': '583', '...
# 3      8024  [{'id': '231513', 'from': {'clubID': '189', 'c...
# 4     72347  [{'id': '186730', 'from': {'clubID': '4835', '...
# ..      ...                                                ...
# 963   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 964   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 965   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 966  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 967   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0    [Bauru Atletico Clube (1952-1956), FC Santos (...
# 1                           [CF Andorinha (1992-1995)]
# 2    [Grandoli FC (1992-1995), Newell's Old Boys (1...
# 3                                                  NaN
# 4         [SC 1906 München, FC Bayern München (-1964)]
# ..                                                 ...
# 963  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 964  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 965                             [Takarazuka Junior FC]
# 966  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 967                                                NaN
#
#                       updatedAt
# 0    2024-11-26T22:21:31.862067
# 1    2024-11-26T22:21:32.848502
# 2    2024-11-26T22:21:34.169456
# 3    2024-11-26T22:21:37.041589
# 4    2024-11-26T22:21:45.622650
# ..                          ...
# 963  2024-11-26T22:52:30.260835
# 964  2024-11-26T22:52:31.366344
# 965  2024-11-26T22:52:32.315595
# 966  2024-11-26T22:52:33.293869
# 967  2024-11-26T22:52:34.763699
#
# [967 rows x 4 columns]

# %%
bad_names
# Out:
# ['Luisito Suarez',
#  'Park Ji-Sung',
#  'Harald Schumacher',
#  'Valery Voronin',
#  'Albert Shesternyov',
#  'Joao Resende Alves',
#  'Jose Augusto Torres',
#  'Packie Bonner',
#  'Yevgeniy Rudakov',
#  'Andras Toroczik',
#  'Emerson (1976)',
#  'Maicon Sisenando',
#  'Seol Ki-Hyeon',
#  'Yordan Letchkov',
#  'Frankie Vercauteren',
#  'Oleg Protassov',
#  'Alberto Costa Pereira',
#  'Pepillo II',
#  'Vladimir Muntyan',
#  'Stoicho Mladenov',
#  'Helmuth Duckadam',
#  'Robby Langers',
#  'Antonios Nikopolidis',
#  'Sergei Kiriakov',
#  'Nikos Machlas',
#  'Yuri Zhirkov',
#  'Son Heung-Min',
#  'Naldo (1982)',
#  'Paul Robinson (GK)',
#  'Gabby Agbonlahor',
#  'Koo Ja-Cheol',
#  'Papiss Cisse']

# %%
players_df = df
players_df
# Out:
#          id                                          transfers  \
# 0     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# 1      8198  [{'id': '4197140', 'from': {'clubID': '515', '...
# 2     28003  [{'id': '4418847', 'from': {'clubID': '583', '...
# 3      8024  [{'id': '231513', 'from': {'clubID': '189', 'c...
# 4     72347  [{'id': '186730', 'from': {'clubID': '4835', '...
# ..      ...                                                ...
# 963   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 964   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 965   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 966  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 967   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0    [Bauru Atletico Clube (1952-1956), FC Santos (...
# 1                           [CF Andorinha (1992-1995)]
# 2    [Grandoli FC (1992-1995), Newell's Old Boys (1...
# 3                                                  NaN
# 4         [SC 1906 München, FC Bayern München (-1964)]
# ..                                                 ...
# 963  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 964  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 965                             [Takarazuka Junior FC]
# 966  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 967                                                NaN
#
#                       updatedAt
# 0    2024-11-26T22:21:31.862067
# 1    2024-11-26T22:21:32.848502
# 2    2024-11-26T22:21:34.169456
# 3    2024-11-26T22:21:37.041589
# 4    2024-11-26T22:21:45.622650
# ..                          ...
# 963  2024-11-26T22:52:30.260835
# 964  2024-11-26T22:52:31.366344
# 965  2024-11-26T22:52:32.315595
# 966  2024-11-26T22:52:33.293869
# 967  2024-11-26T22:52:34.763699
#
# [967 rows x 4 columns]

# %%
def add_player_to_df(player_name):
    global players_df
    id_response_json = requests.get(f"http://localhost:8000/players/search/{player_name}").json()
    if id_response_json["results"]:
        player_id = id_response_json['results'][0]["id"]
        teams_response = requests.get(f"http://localhost:8000/players/{player_id}/transfers")
        players_df = pd.concat([pd.DataFrame([teams_response.json()]), players_df], ignore_index=True)
    else:
        print(f"Failed for {player_name}")
players_to_add = ["Ji-Sung Park", "Heung-Min Son", "Gabriel Agbonlahor", "Maicon"]
for player in players_to_add: add_player_to_df(player)
players_df
# Out:
#          id                                          transfers  \
# 0     18301  [{'id': '3759892', 'from': {'clubID': '10747',...
# 1     37148  [{'id': '2438804', 'from': {'clubID': '405', '...
# 2     91845  [{'id': '1330448', 'from': {'clubID': '15', 'c...
# 3      4592  [{'id': '1059677', 'from': {'clubID': '1039', ...
# 4     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# ..      ...                                                ...
# 966   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 967   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 968   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 969  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 970   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0                         [Grêmio, Criciúma, Cruzeiro]
# 1     [Great Barr Falcons, Aston Villa FC (1994-2005)]
# 2       [Chuncheon Kasan Elementary School (춘천가산초등학교)]
# 3            [Suwon Technical High School (1996-1998)]
# 4    [Bauru Atletico Clube (1952-1956), FC Santos (...
# ..                                                 ...
# 966  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 967  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 968                             [Takarazuka Junior FC]
# 969  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 970                                                NaN
#
#                       updatedAt
# 0    2024-11-26T22:53:35.738177
# 1    2024-11-26T22:53:32.468485
# 2    2024-11-26T22:53:31.512639
# 3    2024-11-26T22:53:29.475526
# 4    2024-11-26T22:21:31.862067
# ..                          ...
# 966  2024-11-26T22:52:30.260835
# 967  2024-11-26T22:52:31.366344
# 968  2024-11-26T22:52:32.315595
# 969  2024-11-26T22:52:33.293869
# 970  2024-11-26T22:52:34.763699
#
# [971 rows x 4 columns]

# %%
add_player_to_df("Deco")

# %%
players_df
# Out:
#          id                                          transfers  \
# 0     18301  [{'id': '3759892', 'from': {'clubID': '10747',...
# 1     37148  [{'id': '2438804', 'from': {'clubID': '405', '...
# 2     91845  [{'id': '1330448', 'from': {'clubID': '15', 'c...
# 3      4592  [{'id': '1059677', 'from': {'clubID': '1039', ...
# 4     48930  [{'id': '2539881', 'from': {'clubID': '37239',...
# ..      ...                                                ...
# 930   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 931   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 932   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 933  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 934  292706  [{'id': '1400213', 'from': {'clubID': '24232',...
#
#                                             youthClubs  \
# 0                         [Grêmio, Criciúma, Cruzeiro]
# 1     [Great Barr Falcons, Aston Villa FC (1994-2005)]
# 2       [Chuncheon Kasan Elementary School (춘천가산초등학교)]
# 3            [Suwon Technical High School (1996-1998)]
# 4                                                  NaN
# ..                                                 ...
# 930  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 931  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 932                             [Takarazuka Junior FC]
# 933  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 934                                                NaN
#
#                       updatedAt detail
# 0    2024-11-26T21:09:39.051018    NaN
# 1    2024-11-26T21:07:27.317660    NaN
# 2    2024-11-26T21:07:26.142119    NaN
# 3    2024-11-26T21:07:23.735182    NaN
# 4    2024-11-26T19:40:55.549917    NaN
# ..                          ...    ...
# 930  2024-11-26T21:03:40.157044    NaN
# 931  2024-11-26T21:03:41.365562    NaN
# 932  2024-11-26T21:03:56.042091    NaN
# 933  2024-11-26T21:03:57.374589    NaN
# 934  2024-11-26T21:03:58.360503    NaN
#
# [935 rows x 5 columns]

# %%
players_df.id.value_counts()
# Out:
# 176910    2
# 18301     1
# 215972    1
# 235941    1
# 293546    1
#          ..
# 141046    1
# 128892    1
# 165411    1
# 145788    1
# 37171     1
# Name: id, Length: 970, dtype: int64

# %%
 players_df[players_df['id'].isin(players_df['id'][players_df['id'].duplicated()])]
# Out:
#          id                                          transfers youthClubs  \
# 460  176910  [{'id': '556843', 'from': {'clubID': '22', 'cl...        NaN
# 654  176910  [{'id': '556843', 'from': {'clubID': '22', 'cl...        NaN
#
#                       updatedAt
# 460  2024-11-26T22:36:50.212245
# 654  2024-11-26T22:42:59.302891

# %%
players_df = players_df.reset_index(drop=True)

# %%
 players_df[players_df['id'].isin(players_df['id'][players_df['id'].duplicated()])]
# Out:
# Empty DataFrame
# Columns: [id, transfers, youthClubs, updatedAt]
# Index: []

# %%
players = players[["id", "player_name"]]
players.to_csv('players_medium.csv', index=False)

# %%
players[players.id=="2309842"]
# Out:
# Empty DataFrame
# Columns: [id, player_name]
# Index: []

# %%
players_df
# Out:
#          id                                          transfers  \
# 0     18301  [{'id': '3759892', 'from': {'clubID': '10747',...
# 1     37148  [{'id': '2438804', 'from': {'clubID': '405', '...
# 2     91845  [{'id': '1330448', 'from': {'clubID': '15', 'c...
# 3      4592  [{'id': '1059677', 'from': {'clubID': '1039', ...
# 4     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# ..      ...                                                ...
# 965   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 966   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 967   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 968  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 969   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0                         [Grêmio, Criciúma, Cruzeiro]
# 1     [Great Barr Falcons, Aston Villa FC (1994-2005)]
# 2       [Chuncheon Kasan Elementary School (춘천가산초등학교)]
# 3            [Suwon Technical High School (1996-1998)]
# 4    [Bauru Atletico Clube (1952-1956), FC Santos (...
# ..                                                 ...
# 965  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 966  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 967                             [Takarazuka Junior FC]
# 968  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 969                                                NaN
#
#                       updatedAt
# 0    2024-11-26T22:53:35.738177
# 1    2024-11-26T22:53:32.468485
# 2    2024-11-26T22:53:31.512639
# 3    2024-11-26T22:53:29.475526
# 4    2024-11-26T22:21:31.862067
# ..                          ...
# 965  2024-11-26T22:52:30.260835
# 966  2024-11-26T22:52:31.366344
# 967  2024-11-26T22:52:32.315595
# 968  2024-11-26T22:52:33.293869
# 969  2024-11-26T22:52:34.763699
#
# [970 rows x 4 columns]

# %%
id_response_json = requests.get(f"http://localhost:8000/players/search/Neymar").json()
player_id = id_response_json['results'][0]["id"]
teams_response = requests.get(f"http://localhost:8000/players/{player_id}/transfers")
print(teams_response.json())
# Out:
# {'id': '68290', 'transfers': [{'id': '4585197', 'from': {'clubID': '583', 'clubName': 'Paris SG'}, 'to': {'clubID': '1114', 'clubName': 'Al-Hilal'}, 'date': 'Aug 15, 2023', 'upcoming': False, 'season': '23/24', 'marketValue': '€60.00m', 'fee': '€90.00m'}, {'id': '1866385', 'from': {'clubID': '131', 'clubName': 'Barcelona'}, 'to': {'clubID': '583', 'clubName': 'Paris SG'}, 'date': 'Aug 3, 2017', 'upcoming': False, 'season': '17/18', 'marketValue': '€100.00m', 'fee': '€222.00m'}, {'id': '874846', 'from': {'clubID': '221', 'clubName': 'Santos'}, 'to': {'clubID': '131', 'clubName': 'Barcelona'}, 'date': 'Jul 1, 2013', 'upcoming': False, 'season': '13/14', 'marketValue': '€50.00m', 'fee': '€88.00m'}, {'id': '271376', 'from': {'clubID': '9540', 'clubName': 'Santos U20'}, 'to': {'clubID': '221', 'clubName': 'Santos'}, 'date': 'Jan 1, 2009', 'upcoming': False, 'season': '08/09'}], 'updatedAt': '2024-11-07T23:07:35.572834'}

# %%
transfers.iloc[0]['transfers']
# Out:
# [{'id': '938001',
#   'from': {'clubID': '2462', 'clubName': 'Fluminense'},
#   'to': {'clubID': '123', 'clubName': 'Retired'},
#   'date': 'Aug 26, 2013',
#   'upcoming': False,
#   'season': '13/14',
#   'marketValue': '€500k'},
#  {'id': '463511',
#   'from': {'clubID': '631', 'clubName': 'Chelsea'},
#   'to': {'clubID': '2462', 'clubName': 'Fluminense'},
#   'date': 'Aug 6, 2010',
#   'upcoming': False,
#   'season': '10/11',
#   'marketValue': '€10.00m',
#   'fee': 'free transfer'},
#  {'id': '206175',
#   'from': {'clubID': '131', 'clubName': 'Barcelona'},
#   'to': {'clubID': '631', 'clubName': 'Chelsea'},
#   'date': 'Jul 1, 2008',
#   'upcoming': False,
#   'season': '08/09',
#   'marketValue': '€18.00m',
#   'fee': '€10.00m'},
#  {'id': '32668',
#   'from': {'clubID': '720', 'clubName': 'FC Porto'},
#   'to': {'clubID': '131', 'clubName': 'Barcelona'},
#   'date': 'Jul 6, 2004',
#   'upcoming': False,
#   'season': '04/05',
#   'fee': '€21.00m'},
#  {'id': '12552',
#   'from': {'clubID': '2434', 'clubName': 'Salgueiros'},
#   'to': {'clubID': '720', 'clubName': 'FC Porto'},
#   'date': 'Mar 31, 1999',
#   'upcoming': False,
#   'season': '98/99',
#   'fee': '€8.00m'},
#  {'id': '791745',
#   'from': {'clubID': '294', 'clubName': 'Benfica'},
#   'to': {'clubID': '2434', 'clubName': 'Salgueiros'},
#   'date': 'Jul 1, 1998',
#   'upcoming': False,
#   'season': '98/99',
#   'fee': 'free transfer'},
#  {'id': '791746',
#   'from': {'clubID': '2521', 'clubName': 'Alverca'},
#   'to': {'clubID': '294', 'clubName': 'Benfica'},
#   'date': 'Jun 30, 1998',
#   'upcoming': False,
#   'season': '97/98',
#   'fee': 'End of loan'},
#  {'id': '791747',
#   'from': {'clubID': '294', 'clubName': 'Benfica'},
#   'to': {'clubID': '2521', 'clubName': 'Alverca'},
#   'date': 'Jul 2, 1997',
#   'upcoming': False,
#   'season': '97/98',
#   'fee': 'loan transfer'},
#  {'id': '791748',
#   'from': {'clubID': '199', 'clubName': 'Corinthians'},
#   'to': {'clubID': '294', 'clubName': 'Benfica'},
#   'date': 'Jul 1, 1997',
#   'upcoming': False,
#   'season': '97/98',
#   'fee': '€4.00m'},
#  {'id': '791749',
#   'from': {'clubID': '1711', 'clubName': 'Nacional-SP'},
#   'to': {'clubID': '199', 'clubName': 'Corinthians'},
#   'date': 'May 1, 1996',
#   'upcoming': False,
#   'season': '95/96',
#   'fee': 'free transfer'}]

# %%
transfers = players_df[['transfers']]
formatted_df = pd.DataFrame(columns=["player_id", "team_name", "start_date", "end_date"])
for i, row in transfers.iterrows():
    row = row[0]
    for j, transfer in enumerate(row):
        new_row_dict = {}
        if transfer["to"]["clubName"] not in ["Retired", "Without Club", "Career break"]: 
            new_row_dict["player_id"] = int(players_df.iloc[i]["id"])
            new_row_dict["team_name"] = transfer["to"]["clubName"]
            new_row_dict["start_date"] = transfer["date"]
            if j>0: new_row_dict["end_date"] = row[j-1]["date"]
            else: new_row_dict["end_date"] = np.nan
            formatted_df = pd.concat([formatted_df, pd.DataFrame([new_row_dict])], ignore_index=True)
formatted_df
# Out:
#      player_id    team_name    start_date      end_date
# 0        18301    Tre Penne   Jul 1, 2021  Jul 16, 2021
# 1        18301         Sona   Jan 4, 2021   Jul 1, 2021
# 2        18301   Villa Nova  Sep 17, 2020   Jan 4, 2021
# 3        18301  Criciúma EC   Jan 1, 2019  Dec 31, 2019
# 4        18301      Avaí FC  May 25, 2017   Jan 1, 2018
# ...        ...          ...           ...           ...
# 6816     37171   Birmingham  Jan 11, 2017  Jun 30, 2017
# 6817     37171    West Brom   Jul 1, 2014  Jan 11, 2017
# 6818     37171   Sunderland   Jul 1, 2011   Jul 1, 2014
# 6819     37171   Birmingham  Jan 26, 2010   Jul 1, 2011
# 6820     37171  Aston Villa   Jan 1, 2006  Jan 26, 2010
#
# [6821 rows x 4 columns]

# %%
formatted_df[formatted_df["player_id"]==28003]
# Out:
#    player_id    team_name    start_date      end_date
# 46     28003        Miami  Jul 15, 2023           NaN
# 47     28003     Paris SG  Aug 10, 2021  Jul 15, 2023
# 48     28003    Barcelona   Jul 1, 2005  Aug 10, 2021
# 49     28003  Barcelona B   Mar 5, 2004   Jul 1, 2005
# 50     28003  Barcelona C  Nov 28, 2003   Mar 5, 2004
# 51     28003    Barça U19  Sep 13, 2003  Nov 28, 2003
# 52     28003    Barça U16   Jul 1, 2002  Sep 13, 2003
# 53     28003  Barça Youth   Jul 1, 2000   Jul 1, 2002

# %%
formatted_df["team_name"].value_counts()
# Out:
# Inter              101
# Barcelona          101
# Chelsea            100
# Juventus            95
# Real Madrid         89
#                   ...
# CD Toledo            1
# Kispesti AC          1
# Inter B              1
# Beerschot VAV        1
# Shimizu S-Pulse      1
# Name: team_name, Length: 1778, dtype: int64

# %%
formatted_df["team_name"] = formatted_df["team_name"].replace("Milan", "AC Milan")

# %%
from difflib import SequenceMatcher
def similarity(str1, str2):
    return SequenceMatcher(None, str1, str2).ratio()

# %%
teams_list = pd.read_csv('teams_medium.csv', index_col=0)
teams_list

# %%
for team in teams_list["team_name"]: print(team)

# %%
similarity("west ham", "west brom")

# %%
counts = formatted_df["team_name"].value_counts()
for name, count in counts.iteritems():
    closest_team, max_sim = "", 0
    for team in teams_list["team_name"]:
        sim = similarity(name, team)
        if sim>max_sim: 
            max_sim = sim
            closest_team = team
    print(name, closest_team)

# %%
formatted_df_cleaned_ids = formatted_df.copy()
counts = formatted_df["team_name"].value_counts().rank(method="first", ascending=False).astype(int)
formatted_df_cleaned_ids["team_name"] = formatted_df_cleaned_ids["team_name"].map(counts)
formatted_df_cleaned_ids.rename(columns={'team_name': 'team_id'}, inplace=True)
formatted_df_cleaned_ids
# Out:
#      player_id  team_id    start_date      end_date
# 0        18301     1205   Jul 1, 2021  Jul 16, 2021
# 1        18301     1763   Jan 4, 2021   Jul 1, 2021
# 2        18301     1401  Sep 17, 2020   Jan 4, 2021
# 3        18301     1400   Jan 1, 2019  Dec 31, 2019
# 4        18301      726  May 25, 2017   Jan 1, 2018
# ...        ...      ...           ...           ...
# 6816     37171       47  Jan 11, 2017  Jun 30, 2017
# 6817     37171       53   Jul 1, 2014  Jan 11, 2017
# 6818     37171       42   Jul 1, 2011   Jul 1, 2014
# 6819     37171       47  Jan 26, 2010   Jul 1, 2011
# 6820     37171       13   Jan 1, 2006  Jan 26, 2010
#
# [6821 rows x 4 columns]

# %%
formatted_df_cleaned_ids["start_date"] = pd.to_datetime(formatted_df_cleaned_ids["start_date"]).dt.strftime('%m/%d/%Y')
formatted_df_cleaned_ids["end_date"] = pd.to_datetime(formatted_df_cleaned_ids["end_date"]).dt.strftime('%m/%d/%Y')

# %%
formatted_df_cleaned_ids.to_csv('players_and_teams_medium.csv', index=True, index_label="id")

# %%
formatted_df
# Out:
#      player_id    team_name    start_date      end_date
# 0        18301    Tre Penne   Jul 1, 2021  Jul 16, 2021
# 1        18301         Sona   Jan 4, 2021   Jul 1, 2021
# 2        18301   Villa Nova  Sep 17, 2020   Jan 4, 2021
# 3        18301  Criciúma EC   Jan 1, 2019  Dec 31, 2019
# 4        18301      Avaí FC  May 25, 2017   Jan 1, 2018
# ...        ...          ...           ...           ...
# 6816     37171   Birmingham  Jan 11, 2017  Jun 30, 2017
# 6817     37171    West Brom   Jul 1, 2014  Jan 11, 2017
# 6818     37171   Sunderland   Jul 1, 2011   Jul 1, 2014
# 6819     37171   Birmingham  Jan 26, 2010   Jul 1, 2011
# 6820     37171  Aston Villa   Jan 1, 2006  Jan 26, 2010
#
# [6821 rows x 4 columns]

# %%
counts = formatted_df["team_name"].value_counts().rank(method="first", ascending=False).astype(int)
counts
# Out:
# Inter                 1
# Barcelona             2
# Chelsea               3
# AC Milan              4
# Juventus              5
#                    ...
# CD Toledo          1773
# Kispesti AC        1774
# Inter B            1775
# Beerschot VAV      1776
# Shimizu S-Pulse    1777
# Name: team_name, Length: 1777, dtype: int64

# %%
teams_df = pd.DataFrame({
    "id": counts.values,
    "team_name": counts.index
}).sort_values(by="id").reset_index(drop=True)
teams_df.to_csv('teams_medium.csv', index=False)

# %%
teams_df
# Out:
#         id        team_name
# 0        1            Inter
# 1        2        Barcelona
# 2        3          Chelsea
# 3        4         AC Milan
# 4        5         Juventus
# ...    ...              ...
# 1772  1773        CD Toledo
# 1773  1774      Kispesti AC
# 1774  1775          Inter B
# 1775  1776    Beerschot VAV
# 1776  1777  Shimizu S-Pulse
#
# [1777 rows x 2 columns]

# %%
formatted_df[formatted_df["team_name"]=="AC Milan"]
# Out:
#      player_id team_name    start_date      end_date
# 80        3140  AC Milan  Jan 30, 2007   Jul 1, 2008
# 86       74471  AC Milan   Jul 1, 1987  Aug 17, 1995
# 126     101045  AC Milan   Jul 1, 1994   Nov 8, 1994
# 128     101045  AC Milan   Jul 1, 1987   Jul 1, 1993
# 136       3522  AC Milan  Aug 23, 2008  Jun 30, 2009
# ...        ...       ...           ...           ...
# 5202     82442  AC Milan  Jul 17, 2021  Jul 18, 2024
# 5354      5758  AC Milan   Jul 1, 1996   Jan 1, 1998
# 5722      4357  AC Milan   Aug 7, 2009  Aug 30, 2010
# 6331      3699  AC Milan  Sep 16, 1994   Jul 1, 1996
# 6546     33873  AC Milan  Jan 13, 2020  Aug 31, 2020
#
# [99 rows x 4 columns]

# %%
teams_response = requests.get(f"http://localhost:8000/players/74471/transfers")
print(teams_response.json())
# Out:
# {'id': '74471', 'transfers': [{'id': '192727', 'from': {'clubID': '5', 'clubName': 'Milan'}, 'to': {'clubID': '123', 'clubName': 'Retired'}, 'date': 'Aug 17, 1995', 'upcoming': False, 'season': '95/96'}, {'id': '192728', 'from': {'clubID': '610', 'clubName': 'Ajax'}, 'to': {'clubID': '5', 'clubName': 'Milan'}, 'date': 'Jul 1, 1987', 'upcoming': False, 'season': '87/88', 'fee': '€1.13m'}, {'id': '636672', 'from': {'clubID': '2824', 'clubName': 'Ajax U19'}, 'to': {'clubID': '610', 'clubName': 'Ajax'}, 'date': 'Jul 1, 1982', 'upcoming': False, 'season': '82/83'}, {'id': '1476319', 'from': {'clubID': '52649', 'clubName': 'Elinkwijk U19'}, 'to': {'clubID': '2824', 'clubName': 'Ajax U19'}, 'date': 'Jul 1, 1981', 'upcoming': False, 'season': '81/82', 'fee': 'free transfer'}], 'youthClubs': ['UVV Utrecht (-1980)', 'USV Elinkwijk (1980-1981)', 'Ajax (1981-1982)'], 'updatedAt': '2024-11-07T23:08:55.240836'}

# %%
players = pd.read_csv("players_medium.csv")
players
# Out:
#          id        player_name
# 0     17121               Pele
# 1      8198  Cristiano Ronaldo
# 2     28003       Lionel Messi
# 3      8024     Diego Maradona
# 4     72347  Franz Beckenbauer
# ..      ...                ...
# 963   28335  Christophe Jallet
# 964   61651   Jordan Henderson
# 965   79642     Shinji Okazaki
# 966  182877    Anthony Martial
# 967   37171      Craig Gardner
#
# [968 rows x 2 columns]

# %%
def add_player_to_players(player_name):
    global players
    id_response_json = requests.get(f"http://localhost:8000/players/search/{player_name}").json()
    if id_response_json["results"]:
        player_id = id_response_json['results'][0]["id"]
        players = pd.concat([pd.DataFrame([{"id": player_id, "player_name": player_name}]), players], ignore_index=True)
    else:
        print(f"Failed for {player_name}")
add_player_to_players("Deco")

# %%
for player in ["Ji-Sung Park", "Heung-Min Son", "Gabriel Agbonlahor", "Maicon"]:
    add_player_to_players(player)

# %%
players.to_csv('players_medium.csv', index=False)

# %%
players[players["player_name"]=="Cesare Maldini"]
# Out:
#        id     player_name
# 511  5803  Cesare Maldini

# %%
players[players["player_name"]=="Paolo Maldini"]
# Out:
#       id    player_name
# 57  5803  Paolo Maldini

# %%
formatted_df[formatted_df["player_id"]==5803]
# Out:
#      player_id team_name   start_date     end_date
# 401       5803  AC Milan  Jul 1, 1985  Jul 1, 2009
# 3556      5803  AC Milan  Jul 1, 1985  Jul 1, 2009

# %%
id_response_json = requests.get(f"http://localhost:8000/players/search/Cesare Maldini").json()
player_id = id_response_json['results'][0]["id"]
teams_response = requests.get(f"http://localhost:8000/players/{player_id}/transfers")
print(teams_response.json())
# Out:
# {'id': '5803', 'transfers': [{'id': '282772', 'from': {'clubID': '5', 'clubName': 'AC Milan'}, 'to': {'clubID': '123', 'clubName': 'Retired'}, 'date': 'Jul 1, 2009', 'upcoming': False, 'season': '09/10'}, {'id': '17523', 'from': {'clubID': '10958', 'clubName': 'Milan U19'}, 'to': {'clubID': '5', 'clubName': 'Milan'}, 'date': 'Jul 1, 1985', 'upcoming': False, 'season': '85/86'}], 'youthClubs': ['Milan'], 'updatedAt': '2024-11-19T06:35:53.674705'}

# %%
players.id.value_counts()[lambda x: x == 2]
# Out:
# 5803      2
# 7515      2
# 176910    2
# 145344    2
# Name: id, dtype: int64

# %%
formatted_df[formatted_df["player_id"]==8198]
# Out:
#    player_id        team_name    start_date      end_date
# 35      8198         Al-Nassr   Jan 1, 2023           NaN
# 36      8198          Man Utd  Aug 31, 2021  Nov 22, 2022
# 37      8198         Juventus  Jul 10, 2018  Aug 31, 2021
# 38      8198      Real Madrid   Jul 6, 2009  Jul 10, 2018
# 39      8198          Man Utd  Aug 12, 2003   Jul 6, 2009
# 40      8198      Sporting CP   Jul 1, 2002  Aug 12, 2003
# 41      8198     Sporting U19   Jul 1, 2000   Jul 1, 2002
# 42      8198     Sporting U17   Jul 1, 1998   Jul 1, 2000
# 43      8198  Sporting Sub-15   Jul 1, 1997   Jul 1, 1998
# 44      8198     Nacional U15   Jul 1, 1996   Jul 1, 1997
# 45      8198    Nacional Yth.   Jul 1, 1995   Jul 1, 1996

# %%
players_df
# Out:
#          id                                          transfers  \
# 0      8564  [{'id': '938001', 'from': {'clubID': '2462', '...
# 1      4592  [{'id': '1059677', 'from': {'clubID': '1039', ...
# 2     91845  [{'id': '1330448', 'from': {'clubID': '15', 'c...
# 3     18301  [{'id': '3759892', 'from': {'clubID': '10747',...
# 4     17121  [{'id': '27815', 'from': {'clubID': '4835', 'c...
# ..      ...                                                ...
# 966   28335  [{'id': '2946756', 'from': {'clubID': '1416', ...
# 967   61651  [{'id': '4831591', 'from': {'clubID': '7732', ...
# 968   79642  [{'id': '4909451', 'from': {'clubID': '475', '...
# 969  182877  [{'id': '5277762', 'from': {'clubID': '515', '...
# 970   37171  [{'id': '2924972', 'from': {'clubID': '337', '...
#
#                                             youthClubs  \
# 0                                 [Nacional São Paulo]
# 1            [Suwon Technical High School (1996-1998)]
# 2       [Chuncheon Kasan Elementary School (춘천가산초등학교)]
# 3                         [Grêmio, Criciúma, Cruzeiro]
# 4    [Bauru Atletico Clube (1952-1956), FC Santos (...
# ..                                                 ...
# 966  [UA Cognac (1992–1998), Chamois Niortais FC (1...
# 967  [Fulwell Juniors (1996-1998), AFC Sunderland (...
# 968                             [Takarazuka Junior FC]
# 969  [CO Les Ulis (2001-2009), Olympique Lyonnais (...
# 970                                                NaN
#
#                       updatedAt
# 0    2024-11-07T23:07:33.686690
# 1    2024-11-07T23:07:30.365063
# 2    2024-11-07T23:07:28.711638
# 3    2024-11-07T23:07:26.972802
# 4    2024-11-07T22:02:41.387407
# ..                          ...
# 966  2024-11-07T22:26:59.976866
# 967  2024-11-07T22:27:01.624904
# 968  2024-11-07T22:27:03.034920
# 969  2024-11-07T22:27:04.494740
# 970  2024-11-07T22:27:05.970156
#
# [971 rows x 4 columns]

# %%
players[players['id'].isin(players['id'][players['id'].duplicated()])]
# Out:
#          id         player_name
# 5      8198   Cristiano Ronaldo
# 11     8198             Ronaldo
# 57     5803       Paolo Maldini
# 85   145344  Alessandro Mazzola
# 293  145344      Sandro Mazzola
# 320    8198                Cris
# 343    7515              Michel
# 460  176910          Franny Lee
# 511    5803      Cesare Maldini
# 654  176910         Francis Lee
# 776    7515      Michel Salgado

# %%
players.at[11, "id"] = "3140"
players.at[511, "id"] = "Cesare Maldini"
# Out:
#       id player_name
# 11  3140     Ronaldo

# %%
players.dtypes
# Out:
# id             object
# player_name    object
# dtype: object

# %%
from datetime import datetime, timedelta
threshold_date = datetime.now() - timedelta(days=15*365)
for index, row in formatted_df_cleaned_ids.iterrows():
    if pd.isna(row['end_date']) and pd.to_datetime(row['start_date'], format='%m/%d/%Y')  <= threshold_date:
        print(f"Row {index} has a start_date {row['start_date']} that is 15 years or more in the past.")
# Out:
# Row 833 has a start_date 07/01/1953 that is 15 years or more in the past.
# Row 992 has a start_date 07/01/2009 that is 15 years or more in the past.
# Row 2522 has a start_date 07/01/1963 that is 15 years or more in the past.
# Row 4108 has a start_date 03/01/1953 that is 15 years or more in the past.
# Row 4206 has a start_date 07/01/1969 that is 15 years or more in the past.

# %%
formatted_df_cleaned_ids["start_date"]
# Out:
# pandas.core.series.Series

# %%
formatted_df_cleaned_ids.iloc[4206]
# Out:
# player_id         237386
# team_id              440
# start_date    07/01/1969
# end_date             NaN
# Name: 4206, dtype: object
